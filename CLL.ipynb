# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class CLL:
    def __init__(self):
        self.head  = None
    def prepend(self,data):
        new_node = Node(data)
        cur  = self.head
        new_node.next = self.head
        if not self.head:
            new_node.next = new_node
        else:
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node    
        self.head = new_node
        
    def append(self,data):
        if not self.head: ##### means no node in the lists
            self.head = Node(data)    #### make one node in the list
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head
    def print_LL(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break
                
                
                
                
Cll1 = CLL()
Cll1.append("C")
Cll1.append("D")
Cll1.prepend("B")
Cll1.prepend("A")
Cll1.print_LL()
# Out:
# A
# B
# C
# D

# %% [markdown]
# #### Remove Node

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class CLL:
    def __init__(self):
        self.head  = None
    def prepend(self,data):
        new_node = Node(data)
        cur  = self.head
        new_node.next = self.head
        if not self.head:
            new_node.next = new_node
        else:
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node    
        self.head = new_node
        
    def append(self,data):
        if not self.head: ##### means no node in the lists
            self.head = Node(data)    #### make one node in the list
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head
    def print_LL(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break
                
    def  remove(self,key):
        if self.head.data == key:       ######   only for checking the head node or 1st node
                cur = self.head
                while cur.next is not self.head:
                    cur = cur.next
                cur.next = self.head.next    
                self.head = self.head.next
                
           
        else:                          ##### this is for deleting any node rather than 1st node
            cur = self.head
            prev = None
            while cur.next is not self.head:
                prev = cur
                cur = cur.next
                if cur.data == key:
                    prev.next = cur.next
                    cur = cur.next
        
                
                
Cll1 = CLL()
Cll1.append("C")
Cll1.append("D")
Cll1.prepend("B")
Cll1.prepend("A")
Cll1.remove("C")
Cll1.print_LL()
# Out:
# A
# B
# D

# %% [markdown]
# ####  split list

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class CLL:
    def __init__(self):
        self.head  = None
    def prepend(self,data):
        new_node = Node(data)
        cur  = self.head
        new_node.next = self.head
        if not self.head:
            new_node.next = new_node
        else:
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node    
        self.head = new_node
        
    def append(self,data):
        if not self.head: ##### means no node in the lists
            self.head = Node(data)    #### make one node in the list
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head
    def print_LL(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break
                
    def __len__(self):      ##### to calculate the length of the list
        cur = self.head
        count = 0
        while cur:
            count +=1
            cur = cur.next
            if cur == self.head:
                break
        return count
    
    def split_list(self):
           
           size = len(self)
           
           if size==0:
                return None
            
           if size ==1:
                return self.head
           
           mid = size//2
           
           count = 0
           
           prev  =None
           cur = self.head
           while cur and count <mid:
                count +=1
                prev = cur
                cur = cur.next
           
           #print(prev.data)
           #print(cur.data) 
           
           prev.next = self.head
           
           splitCLL = CLL()
           while cur.next is not self.head:
                splitCLL.append(cur.data)
                cur = cur.next
           splitCLL.append(cur.data)

           self.print_LL()
           print("\n")

           splitCLL.print_LL()
            
        
        
        
        
Cll1 = CLL()
Cll1.append("C")
Cll1.append("D")
Cll1.prepend("B")
Cll1.prepend("A")
Cll1.print_LL()
print(len(Cll1))
Cll1.split_list()
# Out:
# A
# B
# C
# D
# 4
# A
# B
#
#
# C
# D

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class CLL:
    
    def __init__(self):
        self.head  = None
    
    def prepend(self,data):
        new_node = Node(data)
        cur  = self.head
        new_node.next = self.head
        if not self.head:
            new_node.next = new_node
        else:
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node    
        self.head = new_node
        
    def append(self,data):
        if not self.head: ##### means no node in the lists
            self.head = Node(data)    #### make one node in the list
            self.head.next = self.head
        else:
            new_node = Node(data)
            cur = self.head
            while cur.next is not self.head:
                cur = cur.next
            cur.next = new_node
            new_node.next = self.head
    
    def print_LL(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            if cur == self.head:
                break
                
    def __len__(self):      ##### to calculate the length of the list
        cur = self.head
        count = 0
        while cur:
            count +=1
            cur = cur.next
            if cur == self.head:
                break
        return count
    
    def split_list(self):
           
           size = len(self)
           
           if size==0:
                return None
            
           if size ==1:
                return self.head
           
           mid = size//2
           
           count = 0
           
           prev  =None
           cur = self.head
           while cur and count <mid:
                count +=1
                prev = cur
                cur = cur.next
           
           #print(prev.data)
           #print(cur.data) 
           
           prev.next = self.head
           
           splitCLL = CLL()
           while cur.next is not self.head:
                splitCLL.append(cur.data)
                cur = cur.next
           splitCLL.append(cur.data)

           self.print_LL()
           print("\n")

           splitCLL.print_LL()
            
        
        
        
        
Cll1 = CLL()
Cll1.append("A")
Cll1.append("B")
Cll1.append("C")
Cll1.append("D")
Cll1.append("E")
Cll1.print_LL()
print(len(Cll1))
Cll1.split_list()
# Out:
# A
# B
# C
# D
# E
# 5
# A
# B
#
#
# C
# D
# E
