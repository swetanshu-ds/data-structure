# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data                   #### data and ref are fields of the node 
        self.ref=None
node1=Node(10)
print(node1)

# %%
class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

# %%
###    traversing through linked list 
###   1.start with the head of the linked list,      Access the data if head is not NULL
###   2..goto next node access node data  ,,,continue until last node

# %% [markdown]
# #####   first check two condition for traversing

# %%
#### 1 .linked list is empty
#### 2.. if it is not empty
###  first condition
### while traversing the L.L. if L.L. is empty then print that L.L. is empty

# %%
###  how to check if L.L. is empty 
### when head is none or null then it means L.L. is empty but if head contains some value then it is not
### if head is none then print L.L. is empty

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data)
                n=n.ref                         ####   3.
LL1=linkedlist()          
LL1.print__LL()

# %% [markdown]
# ##### adding elements at the beginnig  of  the linked list

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data)
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)                 ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# 20
# 10

# %% [markdown]
# #####  adding element at the end  to the end

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data)
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
                
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_end(100)
LL1.add_begin(20)                 ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# 20
# 10
# 100

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
                
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_end(100)
LL1.add_begin(20)                 ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# 20 -----> 10 -----> 100 ----->

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
                
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_end(100)
LL1.add_end(500)
LL1.add_begin(20)                 ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# 20 -----> 10 -----> 100 -----> 500 ----->

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
                
            
LL1=linkedlist()                 ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# L.L. is empty

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
                
            
LL1=linkedlist()
LL1.add_end(500)               ####    first it will show 20 and then it will show 10 becuase first we are adding 10 and then 20 at beginning of the linked list so it will show 20 and then  10
LL1.print__LL()
# Out:
# ...
# 500 ----->

# %% [markdown]
# #####   to add element after a specified node

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
                          
            
LL1=linkedlist()
LL1.add_begin(100)
LL1.add_before(200,100)
LL1.add_before(300,200)
LL1.print__LL()
# Out:
# ...
# 300 -----> 200 -----> 100 ----->

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
            
LL1=linkedlist()
LL1.insert_empty(10)
LL1.insert_empty(20)
LL1.print__LL()
# Out:
# ...
# LL is not empty
# 10 ----->

# %% [markdown]
# ###  removal //    deletion

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.delete_begin()
LL1.print__LL()
# Out:
# ...
# 20 -----> 10 ----->

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
            
LL1=linkedlist()
LL1.delete_begin()
LL1.print__LL()
# Out:
# ...
# LL is empty so we can't delete nodes
# L.L. is empty

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we cant delete nodes")
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
#LL1.delete_begin()
LL1.print__LL()
# Out:
# ...
# 30 -----> 20 -----> 10 ----->

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we cant delete nodes")
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
            
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.delete_begin()
LL1.print__LL()
# Out:
# ...
# 20 -----> 10 ----->

# %%
#####  deleting from end

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we cant delete nodes")
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
            
LL1=linkedlist()
LL1.insert_empty(10)   
LL1.delete_end()                 
LL1.print__LL()
######  showing error because it is in empty list we have inserted only one 
#######  element aqnd when  delete end is called it checked the n.ref.ref but it doesnt found anything so it shows error
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-9cb779ceb8a3> in <module>
#      86 LL1=linkedlist()
#      87 LL1.insert_empty(10)
# ---> 88 LL1.delete_end()
#      89 LL1.print__LL()
#      90 ######  showing error because it is in empty list we have inserted only one element aqnd when  delete end is called it checked the n.ref.ref but it doesnt found anything so it shows error
#
# <ipython-input-4-9cb779ceb8a3> in delete_end(self)
#      80         else:
#      81             n=self.head
# ---> 82             while n.ref.ref is not None:
#      83                 n=n.ref
#      84             n.ref=None
#
# AttributeError: 'NoneType' object has no attribute 'ref'

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we cant delete nodes")
        elif self.head.ref is None:
            self.head=None
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
            
LL1=linkedlist()
LL1.insert_empty(10)   
LL1.delete_end()                 
LL1.print__LL()
# Out:
# ...
# L.L. is empty

# %% [markdown]
# ######  delete any node from any position

# %%
class Node:                                       #######   to create node (1st step)
    def __init__(self,data):
        self.data=data
        self.ref=None
node1=Node(10)
print(node1)

class linkedlist:
    def __init__(self):
        self.head=None         ######  means creating empty node ###  head is the start point of linked list  and none is the empty linked list

    def print__LL(self):         ###     condition 1    when linked list is empty   ####  from here to ### 3. line is the way how to traverse through the linked list
        if self.head is None:
            print("L.L. is empty")
        else:
            n=self.head                        
            while n is not None:            
                print(n.data,"----->",end=" ")
                n=n.ref    ####   3.
    def add_begin(self,data):
        new_node=Node(data)        ######  creating node from the Node class 
        new_node.ref=self.head
        self.head=new_node
    def add_end(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
        else:
            n=self.head
            while n.ref is not None:
                n=n.ref
            n.ref=new_node
    def add_after(self,data,x):
            n=self.head
            while n is not None:
                if x==n.data:
                    break
                    n=n.ref
            if n is None:
                print("node is not present in LL")
            else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    
    def add_before(self,data,x):
        if self.head is None:
            print("linked list is empty")
            return
        if self.head.data==x:
            new_node=Node(data)
            new_node.ref=self.head
            self.head=new_node
            return 
        n=self.head
        while n.ref is not None:
            if n.ref.data==x:
                break
            n=n.ref    
        if n.ref is None:
            print("node is not found")
        else:
                 new_node=Node(data)
                 new_node.ref=n.ref
                 n.ref=new_node
    def insert_empty(self,data):
        if self.head is None:
            new_node=Node(data)
            self.head=new_node
        else:
            print("LL is not empty")
    def delete_begin(self):
        if self.head is None:
            print("LL is empty so we can't delete nodes")
        else:
            self.head=self.head.ref
    def delete_end(self):
        if self.head is None:
            print("LL is empty so we cant delete nodes")
        elif self.head.ref is None:
            self.head=None
        else:
            n=self.head
            while n.ref.ref is not None:
                n=n.ref
            n.ref=None
    def delete_by_value(self,x):
        if self.head is None:          #####     x 
            print("LL is empty so can't delete")
            return       ####  after checking line x condition it will print the message and it will come out of the if condition
        if x==self.head.data:
            self.head=self.head.ref
            return
        n=self.head
        while n.ref is not None:
            if x==n.ref.data:
                 break
            n=n.ref
            if n.ref is None:          ### that means we checked for the whole LL but we didn't found the given node
                print("node is not present")
            else:
                n.ref=n.ref.ref
                
LL1=linkedlist()
LL1.add_begin(10)
LL1.add_begin(20)
LL1.add_begin(30)
LL1.delete_by_value(56)
LL1.print__LL()
# Out:
# ...
# 30 -----> 20 ----->
